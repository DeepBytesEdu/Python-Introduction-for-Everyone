# %% [markdown]
#                                            2.3 if Tests and Syntax Rules
#
# General Format:-
#
#                                            if <test1>: # if test
#
#                                            <statements1> # Associated block
#
#                                            elif <test2>: # Optional elifs
#
#                                            <statements2>
#
#                                            else: # Optional else
#
#                                            <statements3>

# %% [markdown]
# Basic Exaples
#
#                                          if 1:
#                                            print('True')
#                                               ...
#                                               ...
#                                               true

# %% [markdown]
# Multiway Branching

# %%
x='killer rabbit'
if x=='roger':
    print("how's Jessica")
elif x =='bugs':
        print("what's up doc?")
else: 
            print('Run away! Run away')
# Out:
# Run away! Run away

# %%
choice = 'hum'

Dic={'span':'1.25', 'hum': '1.99', 'eggs':'0.99' ,'bacon': '1.10'}

if choice == 'spam':
    print(1.25)
elif choice == 'ham':
    print(1.99)
elif choice == 'bacon':
    print(1.10)
else: 
    print('Bad choice')
# Out:
# Bad choice

# %%
branch = {'spam': 1.25,'ham': 1.99, 'eggs': 0.99}
print(branch.get('spam', 'Bad choice'))
# Out:
# 1.25

# %%
print(branch.get('bacon', 'Bad choice'))
# Out:
# Bad choice

# %%
 choice = 'bacon'
if choice in branch:
        print(branch[choice])
else:
    print('Bad choice')
# Out:
# Bad choice

# %% [markdown]
# Block Delimiters: Indentation Rules

# %%
x=1 
if x:
    y=2 
    if y:
        print('block2')
    print('block1')
print('block0')
# Out:
# block2
# block1
# block0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 'SPAM' # Error: first line indented
if 'rubbery' in 'shrubbery':
    print(x * 8)
    x+='NI' # Error: unexpected indentation
    if x.endswith('NI'):
        x *= 2
    print(x) # Error: inconsistent indentation
# Out:
# SPAMSPAMSPAMSPAMSPAMSPAMSPAMSPAM
# SPAMNISPAMNI

# %% [markdown]
# A Few Special Cases

# %%
L = ["Good", "Bad", "Ugly"] # Open pairs may span lines

# %% [markdown]
# Truth Tests

# %% [markdown]
# The if/else Ternary Expression

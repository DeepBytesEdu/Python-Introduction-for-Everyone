# %% [markdown]
#                                           6.Tuples ,files and Summary of Data Types
#
# Tuples: A collection of other objects that cannot be changed.
#
# Files : An interface to external files on your computer.
#
# Common tuple literals and operations
#
# |Operation|Interpretation|
# |---:|---:|
# |()  | An empty tuple|
# |T=(0,)| A one-item tuple (not an expression)|
# |T=(0, 'Ni', 1.2 ,3)| A four-item tuple |
# |T=0, 'Ni', 1.2, 3| Another four-item tuple (same as prior line)|
# |T= ('abc',('def','ghi'))| Nested Tuples|
# |T= tuple('spam')|Tuple of items in an iterable|
# |T[i], T[i][j], T[i:j], len(T) | Index, Index of Index , slice , lenght |
# |T1+T2 , T*3| Concatenate, repeat|
# | for x in T: print(x), 'spam' in t,[x**2 for x in T]|  Iteration, membership|
# |T.index('Ni'), T.count('Ni')|Search,count |
#
# Tuples in Action:

# %%
(1, 2) + (3, 4) # Concatenation
# Out:
# (1, 2, 3, 4)

# %%
(1, 2) * 4 # Repetition
# Out:
# (1, 2, 1, 2, 1, 2, 1, 2)

# %%
T = (1, 2, 3, 4) # Indexing, slicing
T[0], T[1:3]
# Out:
# (1, (2, 3))

# %% [markdown]
# Tuple syntax peculiarities: Commas and parentheses
#
# We need to do something
# special to tell Python when a single object in parentheses is a tuple object and not a
# simple expression. If you really want a single-item tuple, simply add a trailing comma
# after the single item, before the closing parenthesis:

# %%
x = (40) # An integer!

# %%
y = (40,) # A tuple containing an integer

# %% [markdown]
# Conversions, methods, and immutability

# %%
T = ('cc', 'aa', 'dd', 'bb')

# %%
tmp = list(T)  # Make a list from a tuple's items
tmp.sort() # Sort the list
tmp
# Out:
# ['aa', 'bb', 'cc', 'dd']

# %%
T = tuple(tmp) # Make a tuple from the list's items
T
# Out:
# ('aa', 'bb', 'cc', 'dd')

# %%
sorted(T) # Or use the sorted built-in
# Out:
# ['aa', 'bb', 'cc', 'dd']

# %%
T = (1, 2, 3, 4, 5)
L = [x + 20 for x in T]
L
# Out:
# [21, 22, 23, 24, 25]

# %%
T = (1, 2, 3, 2, 4, 2) # Tuple methods in 2.6 and 3.0

# %%
T.index(2) # Offset of first appearance of 2
# Out:
# 1

# %%
T.index(2, 2) # Offset of appearance after offset 2
# Out:
# 3

# %%
T.count(2) # How many 2s are there?
# Out:
# 3

# %% [markdown]
# Rule about tuple immutability applies only to the top level of the
# tuple itself, not to its contents. A list inside a tuple, for instance, can be changed as usual:

# %%
T = (1, [2, 3], 4)

# %%
T[1] = 'spam' # This fails: can't change tuple itself
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-009ad88d2325> in <module>
# ----> 1 T[1] = 'spam' # This fails: can't change tuple itself
#
# TypeError: 'tuple' object does not support item assignment

# %%
T[1][0] = 'spam' # This works: can change mutables inside

# %%
T
# Out:
# (1, ['spam', 3], 4)

# %% [markdown]
# Why Lists and Tuples?
#
# 1. tuple as a simple association of objects and a list as a data structure that changes over
# time.
#
# 2. Immutability of tuples provides some
# integrity
#
#                                                              Files
#
# An interface to external files on your computer.
#
# Common file Operatons
#
# |Operation|Interpretation|
# |---:|---:|
# |output = open(r'C:\spam', 'w')|Create output file ('w' means write)|
# |input = open('data', 'r')|Create input file ('r' means read)|
# |input = open('data')|Same as prior line ('r' is the default)|
# |aString = input.read()|Read entire file into a single string|
# |aString = input.read(N)|Read up to next N characters (or bytes) into a string|
# |aString = input.readline()|Read next line (including \n newline) into a string|
# |aList = input.readlines()|Read entire file into list of line strings (with \n)|
# |output.write(aString)|Write a string of characters (or bytes) into file|
# |output.writelines(aList)|Write all line strings in a list into file|
# |output.close()|Manual close (done for you when file is collected)|
# |output.flush()|Flush output buffer to disk without closing|
# |anyFile.seek(N)|Change file position to offset N for next operation|
# |for line in open('data'): use line|File iterators read line by line|
# |open('f.txt', encoding='latin-1')|Python 3.0 Unicode text files (str strings)|
# |open('f.bin', 'rb')|Python 3.0 binary bytes files (bytes strings)|

# %% [markdown]
# Opening Files
#
# File in Action

# %%
myfile = open('adfile.txt', 'w') # Open for text output: create/empty

# %%
myfile.write('hello text file\n') # Write a line of text: string
# Out:
# 16

# %%
myfile.write('goodbye text file\n')
# Out:
# 18

# %%
myfile.close() # Flush output buffers to disk

# %%
myfile = open('adfile.txt') # Open for text input: 'r' is default

# %%
myfile.readline() # Read the lines back
# Out:
# 'hello text file\n'

# %%
myfile.readline()
# Out:
# 'goodbye text file\n'

# %%
open('adfile.txt').read() # Read all at once into string
# Out:
# 'hello text file\ngoodbye text file\n'

# %%
print(open('adfile.txt').read()) # User-friendly display
# Out:
# hello text file
# goodbye text file

# %% [markdown]
# Storing and parsing Python objects in files

# %%
X, Y, Z = 43, 44, 45 # Native Python objects
S = 'Spam' # Must be strings to store in file
D = {'a': 1, 'b': 2}
L = [1, 2, 3]

# %%
F = open('addatafile.txt', 'w') # Create output file

# %%
F.write(S + '\n') # Terminate lines with \n
# Out:
# 5

# %%
F.write('%s,%s,%s\n' % (X, Y, Z)) # Convert numbers to strings
# Out:
# 9

# %%
F.write(str(L) + '$' + str(D) + '\n') # Convert and separate with $
# Out:
# 27

# %%
F.close()

# %%
chars = open('addatafile.txt').read() # Raw string display

# %%
chars
# Out:
# "Spam\n43,44,45\n[1, 2, 3]${'a': 1, 'b': 2}\n"

# %%
print(chars) # User-friendly display
# Out:
# Spam
# 43,44,45
# [1, 2, 3]${'a': 1, 'b': 2}

# %%
F = open('addatafile.txt') # Open again

# %%
line = F.readline() # Read one line

# %%
line
# Out:
# 'Spam\n'

# %%
line.rstrip() # Remove end-of-line
# Out:
# 'Spam'

# %%
line = F.readline() # Next line from file

# %%
line # It's a string here
# Out:
# '43,44,45\n'

# %%
parts = line.split(',') # Split (parse) on commas

# %%
parts
# Out:
# ['43', '44', '45\n']

# %%
int(parts[1]) # Convert from string to int
# Out:
# 44

# %%
numbers = [int(P) for P in parts] # Convert all in list at once

# %%
numbers
# Out:
# [43, 44, 45]

# %%
line = F.readline()

# %%
line
# Out:
# "[1, 2, 3]${'a': 1, 'b': 2}\n"

# %%
parts = line.split('$') # Split (parse) on $
parts
# Out:
# ['[1, 2, 3]', "{'a': 1, 'b': 2}\n"]

# %%
eval(parts[0])
# Out:
# [1, 2, 3]

# %%
objects = [eval(P) for P in parts] # Do same for all in list

# %%
objects
# Out:
# [[1, 2, 3], {'a': 1, 'b': 2}]

# %% [markdown]
# Storing native Python objects with pickle: The pickle module is an advanced tool that allows us to store almost any Python object
# in a file directly, with no to- or from-string conversion requirement on our part. It’s like
# a super-general data formatting and parsing utility.

# %%
D = {'a': 1, 'b': 2}
F = open('addatafile.pkl', 'wb')

# %%
import pickle
pickle.dump(D, F) # Pickle any object to file
F.close()

# %%
F = open('addatafile.pkl', 'rb')
E = pickle.load(F) # Load any object from file
E
# Out:
# {'a': 1, 'b': 2}

# %%
open('datafile.pkl', 'rb').read() # Format is prone to change!
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-71-d11f87545498> in <module>
# ----> 1 open('datafile.pkl', 'rb').read() # Format is prone to change!
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datafile.pkl'

# %% [markdown]
# Storing and Parsing packed binary data in files

# %%
F = open('addata.bin', 'wb') # Open binary output file

# %%
import struct
data = struct.pack('>i4sh', 7, b'spam', 8) # Make packed binary data

# %% [markdown]
# struct.pack('>i4sh',7,b'spam',8) means that we're wanting to pack the data as big-endian (>), the second and third characters mean that the 2nd argument should be packed as 4-byte integer (i4), the 4th character means that the 3rd argument should be packed as a char array (s) and the 5th character means that the 4rd argument should be packed as short integer (h). So the total length of this is 10; 4 bytes from 4-byte integer, 4 bytes from the string and 2 bytes from a 2-byte short integer.

# %%
data
# Out:
# b'\x00\x00\x00\x07spam\x00\x08'

# %%
F.write(data) # Write byte string
F.close()

# %%
F = open('addata.bin', 'rb')
data = F.read() # Get packed binary data
data
# Out:
# b'\x00\x00\x00\x07spam\x00\x08\x00\x00\x00\x07spam\x00\x08'

# %%
values = struct.unpack('>i4sh', data) # Convert to Python objects
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-86-045a1d0d425a> in <module>
# ----> 1 values = struct.unpack('>i4sh', data) # Convert to Python objects
#
# error: unpack requires a buffer of 10 bytes

# %% [markdown]
# Object Classification
#
# ![image.png](attachment:image.png)
#
# Objecte Flexibility :
#
# • Lists, dictionaries, and tuples can hold any kind of object.
#
# • Lists, dictionaries, and tuples can be arbitrarily nested.
#
# • Lists and dictionaries can dynamically grow and shrink.

# %%
L = ['abc', [(1, 2), ([3], 4)], 5]

# %%
L[1]
# Out:
# [(1, 2), ([3], 4)]

# %%
L[1][1]
# Out:
# ([3], 4)

# %%
L[1][1][0]
# Out:
# [3]

# %%
L[1][1][0][0]
# Out:
# 3

# %% [markdown]
# Reference vs Copies
#
# ![image.png](attachment:image.png)

# %%
X = [1, 2, 3]
L = ['a', X, 'b'] # Embed references to X's object
D = {'x':X, 'y':2}

# %%
 X[1] = 'surprise' # Changes all three references!

# %%
L
# Out:
# ['a', [1, 'surprise', 3], 'b']

# %%
 D
# Out:
# {'x': [1, 'surprise', 3], 'y': 2}

# %% [markdown]
# ![image.png](attachment:image.png)
#
# For example, say you have a list and a dictionary, and you don’t want their values to
# be changed through other variables:

# %%
L = [1,2,3]

# %%
D = {'a':1, 'b':2}

# %%
A = L[:] # Instead of A = L (or list(L))
B = D.copy() # Instead of B = D (ditto for sets)

# %%
A[1] = 'Ni'
B['c'] = 'spam'
L, D
# Out:
# ([1, 2, 3], {'a': 1, 'b': 2})

# %%
A, B
# Out:
# ([1, 'Ni', 3], {'a': 1, 'b': 2, 'c': 'spam'})

# %% [markdown]
# Comparisons, Equality, and Truth

# %%
L1 = [1, ('a', 3)] # Same value, unique objects
L2 = [1, ('a', 3)]
L1 == L2, L1 is L2 # Equivalent? Same object?
# Out:
# (True, False)

# %% [markdown]
# •The == operator tests value equivalence. Python performs an equivalence test,
# comparing all nested objects recursively.
#
# • The is operator tests object identity. Python tests whether the two are really the
# same object (i.e., live at the same address in memory).
#
# In the preceding example, L1 and L2 pass the == test (they have equivalent values because
# all their components are equivalent) but fail the is check (they reference two different
# objects, and hence two different pieces of memory)

# %%
S1 = 'spam'
S2 = 'spam'
S1 == S2, S1 is S2
# Out:
# (True, True)

# %% [markdown]
# Here, we should again have two distinct objects that happen to have the same value:
# == should be true, and is should be false. But because Python internally caches and
# reuses some strings as an optimization, there really is just a single string 'spam' in
# memory, shared by S1 and S2; hence, the is identity test reports a true result

# %%
S1 = 'a longer string'
S2 = 'a longer string'
S1 == S2, S1 is S2
# Out:
# (True, False)

# %%
L1 = [1, ('a', 3)]
L2 = [1, ('a', 2)]
L1 < L2, L1 == L2, L1 > L2 # Less, equal, greater: tuple of results
# Out:
# (False, False, True)

# %% [markdown]
# Dictionary Comprision :

# %%
D1 = {'a':1, 'b':2}
D2 = {'a':1, 'b':3}
D1 == D2
# Out:
# False

# %% [markdown]
# Python’s Type Hierarchies
#
# ![image.png](attachment:image.png)
